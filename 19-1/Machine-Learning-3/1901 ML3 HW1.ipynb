# %%
import retro

# %%
# ?retro
# Out:
# Type:        module
# String form: <module 'retro' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\retro\\__init__.py'>
# File:        c:\programdata\anaconda3\lib\site-packages\retro\__init__.py
# Docstring:   <no docstring>

# %%
# ?retro.make
# Out:
# Signature: retro.make(game, state=-1, **kwargs)
# Docstring: <no docstring>
# File:      c:\programdata\anaconda3\lib\site-packages\retro\__init__.py
# Type:      function

# %%
# ?retro.data
# Out:
# Object `retro.data` not found.

# %%
def main():
    if 0:
        env = retro.make(game='Bowling-Atari2600') #돌아감
    elif 0 :
        env = retro.make(game='Boxing-Atari2600') #안돌아감
    elif 0:
        env = retro.make(game='AirRaid-Atari2600') #돌아감
    elif 1:
        env = retro.make(game='FishingDerby-Atari2600') #돌아감. 100점 되면 게임 끝
    elif 0:
        env = retro.make(game='Freeway-Atari2600') #돌아감. 길 건너기 게임
    elif 0:
        env = retro.make(game='VideoPinball-Atari2600') #돌아감
    elif 0:
        env = retro.make(game='Tennis-Atari2600') #안돌아감
    obs = env.reset()
    A= True
    while A == True:
        obs, rew, done, info = env.step(env.action_space.sample())
        print (info)
        env.render()
        if done:
            obs = env.reset()
            A=False
            print("game done")
    print("while ended")
    env.close()
    print("env closed")
    


if __name__ == "__main__":
    main()
# Out:
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# {'score1': 0, 'score2': 0}
# ...
